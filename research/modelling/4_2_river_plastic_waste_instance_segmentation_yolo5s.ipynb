# %% [markdown]
# ## Introduction

# %% [markdown]
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# ### YoloV5

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO5, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ## Before you start

# %% [markdown]
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator` and set it to `GPU`.

# %%
# !nvidia-smi
# Out:
# Sat Jan  4 14:23:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0             26W /  250W |       3MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os

os.mkdir('yolo5')

# %%
os.chdir('yolo5')

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working/yolo5/yolov5/yolo5

# %% [markdown]
# ## Install YOLO8 via Ultralytics

# %%
# !git clone https://github.com/ultralytics/yolov5 
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17088, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 17088 (delta 23), reused 7 (delta 7), pack-reused 17051 (from 3)
# Receiving objects: 100% (17088/17088), 15.69 MiB | 27.76 MiB/s, done.
# Resolving deltas: 100% (11723/11723), done.
# /kaggle/working/yolo5/yolov5/yolo5/yolov5
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-392-gf003c3df Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6037.7/8062.4 GB disk)

# %% [markdown]
# ## Fine-tune YOLOV5 on River Plastic Waste Dataset

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
ROBOFLOW_API_KEY = 'QIutYCrEaAHGulBxVoYa'

# %%
# %ls
# Out:
# benchmarks.py    data/       LICENSE         README.zh-CN.md   tutorial.ipynb
# CITATION.cff     detect.py   models/         requirements.txt  utils/
# classify/        export.py   pyproject.toml  segment/          val.py
# CONTRIBUTING.md  hubconf.py  README.md       train.py

# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.50-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.8.30)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.50-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 6.3 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: filetype, python-dotenv, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.50

# %%
# %ls
# Out:
# benchmarks.py    data/       LICENSE         README.zh-CN.md   tutorial.ipynb
# CITATION.cff     detect.py   models/         requirements.txt  utils/
# classify/        export.py   pyproject.toml  segment/          val.py
# CONTRIBUTING.md  hubconf.py  README.md       train.py

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace("project-zero").project("aerial_river_plastic_wastes")
version = project.version(10)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Aerial_River_Plastic_Wastes-10 to yolov5pytorch:: 100%|██████████| 68399/68399 [00:02<00:00, 23507.65it/s]
# Extracting Dataset Version Zip to Aerial_River_Plastic_Wastes-10 in yolov5pytorch:: 100%|██████████| 4938/4938 [00:00<00:00, 7527.85it/s]

# %%
# !ls
# Out:
# Aerial_River_Plastic_Wastes-10	data	    models	      segment
# benchmarks.py			detect.py   pyproject.toml    train.py
# CITATION.cff			export.py   README.md	      tutorial.ipynb
# classify			hubconf.py  README.zh-CN.md   utils
# CONTRIBUTING.md			LICENSE     requirements.txt  val.py

# %% [markdown]
# ## Custom Training

# %% [markdown]
# Before training on our own custom dataset, we'll need do download some pre-trained weights so we aren't starting from scratch. This will accelerate the training process and improve the quality of our results.

# %% [markdown]
# **NOTE:** The results of the completed training are saved in `./yolo8/runs/segment/train/`. Let's examine them.

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-seg' for x in p5]  # segmentation models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5n-seg.pt to weights/yolov5n-seg.pt...
# 100%|██████████| 4.11M/4.11M [00:00<00:00, 139MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s-seg.pt to weights/yolov5s-seg.pt...
# 100%|██████████| 14.9M/14.9M [00:00<00:00, 45.2MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m-seg.pt to weights/yolov5m-seg.pt...
# 100%|██████████| 42.4M/42.4M [00:01<00:00, 40.3MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5l-seg.pt to weights/yolov5l-seg.pt...
# 100%|██████████| 91.9M/91.9M [00:02<00:00, 32.3MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5x-seg.pt to weights/yolov5x-seg.pt...
# 100%|██████████| 170M/170M [00:06<00:00, 29.6MB/s]

# %% [markdown]
# ### Changing Parameters
# `--batch, --epochs, --weights`
#
# #### List of Weights
# - yolov5n-seg.pt
# - yolov5s-seg.pt
# - yolov5m-seg.pt
# - yolov5l-seg.pt
# - yolov5x-seg.pt

# %%
# !python segment/train.py --img 640 --batch 32 --epochs 50 --data ./Aerial_River_Plastic_Wastes-10/data.yaml --weights yolov5s-seg.pt --device 0
# Out:
# 2025-01-04 14:28:09.642561: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-04 14:28:09.830185: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-04 14:28:09.884954: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# segment/train: weights=yolov5s-seg.pt, cfg=, data=./Aerial_River_Plastic_Wastes-10/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-392-gf003c3df Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train-seg', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s-seg.pt to yolov5s-seg.pt...
# 100%|███████████████████████████████████████| 14.9M/14.9M [00:00<00:00, 304MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    404767  models.yolo.Segment                     [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], 32, 128, [128, 256, 512]]
# Model summary: 225 layers, 7410911 parameters, 7410911 gradients, 25.9 GFLOPs
#
# Transferred 361/367 items from yolov5s-seg.pt
# /kaggle/working/yolo5/yolov5/yolo5/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /kaggle/working/yolo5/yolov5/yolo5/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 60 weight(decay=0.0), 63 weight(decay=0.0005), 63 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_W
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_104_jpg.rf.215986c2e3f4e094a9e585a48b7bba2b.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_164_jpg.rf.bc6b89e94298fea908747a03b3ab7419.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_218_jpg.rf.faca709fb1e733438d6dee2922faadf4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_46_jpg.rf.45441f30ab09f136be603494eaefbd90.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_49_jpg.rf.db72febd46544ddc25efbbb29be61181.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_65_jpg.rf.4d56d2250cd3f6622041b3c136856526.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_65_jpg.rf.6b1415a93774f2a346c9185195072e94.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/images/Aerial_Location_1_81_jpg.rf.32e81f2c785edf7f502c68c66bef8773.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/train/labels.cache
# val: Scanning /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Was
# val: New cache created: /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/valid/labels.cache
#
# AutoAnchor: 2.08 anchors/target, 0.948 Best Possible Recall (BPR). Anchors are a poor fit to dataset ⚠️, attempting to improve...
# AutoAnchor: WARNING ⚠️ Extremely small objects found: 1742 of 29456 labels are <3 pixels in size
# AutoAnchor: Running kmeans for 9 anchors on 29436 points...
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.7755: 100%|████
# AutoAnchor: thr=0.25: 0.9993 best possible recall, 4.52 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.308/0.775-mean/best, past_thr=0.552-mean: 4,4, 6,7, 10,8, 8,12, 14,16, 47,37, 92,192, 625,349, 614,397
# AutoAnchor: Done ✅ (optional: update model *.yaml to use these anchors in the future)
# Plotting labels to runs/train-seg/exp/labels.jpg...
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:323: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/train-seg/exp
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/72 [00:00<?, ?it/s]/kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G     0.1548     0.1764    0.03214    0.03186        591   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G     0.1547     0.1851    0.03179    0.03159        522   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G      0.154     0.1828    0.03253    0.03152        541   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G     0.1538     0.1797    0.03228    0.03152        518   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G      0.154     0.1795    0.03226    0.03148        569   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G     0.1536     0.1794    0.03255    0.03153        581   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G     0.1538     0.1777    0.03258    0.03142        537   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G     0.1537     0.1766    0.03255    0.03144        517   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      10.3G     0.1542      0.176    0.03258    0.03152        699   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G      0.154     0.1729    0.03286     0.0316        656   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G      0.154     0.1703     0.0326    0.03157        438   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G      0.154     0.1672    0.03249    0.03158        525   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G      0.154     0.1639    0.03243    0.03156        534   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.1541     0.1603     0.0324    0.03153        569   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G      0.154     0.1572    0.03234    0.03152        555   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G      0.154     0.1545    0.03229    0.03137        467   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.1539     0.1518    0.03235    0.03129        524   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.1538     0.1488     0.0324    0.03119        561   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.1536     0.1459    0.03257    0.03107        617   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.1532     0.1434    0.03257    0.03093        454   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.1528     0.1408     0.0327    0.03075        511   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.1524     0.1382    0.03282    0.03056        512   /kaggle/working/yolo5/yolov5/yolo5/yolov5/segment/train.py:383: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      12.2G     0.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         94       1049       0.83       0.79      0.819       0.64      0.739       0.69      0.673      0.516
#
# 50 epochs completed in 0.845 hours.
# Optimizer stripped from runs/train-seg/exp/weights/last.pt, 15.2MB
# Optimizer stripped from runs/train-seg/exp/weights/best.pt, 15.2MB
#
# Validating runs/train-seg/exp/weights/best.pt...
# Fusing layers...
# Model summary: 165 layers, 7401119 parameters, 0 gradients, 25.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         94       1049      0.815       0.79      0.819      0.638      0.715      0.691      0.677      0.518
#                plastic         94        942       0.67      0.679      0.712      0.385      0.469       0.48      0.429      0.149
#                  river         94        107       0.96      0.901      0.926      0.892       0.96      0.902      0.925      0.887
# Results saved to runs/train-seg/exp

# %%
display.Image(filename=f'runs/train-seg/exp/results.png', width=1200)

# %% [markdown]
# ## Test and Validate the Custom Model

# %%
# !python segment/val.py --weights runs/train-seg/exp/weights/best.pt --data ./Aerial_River_Plastic_Wastes-10/data.yaml --img 640
# Out:
# segment/val: data=./Aerial_River_Plastic_Wastes-10/data.yaml, weights=['runs/train-seg/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val-seg, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-392-gf003c3df Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
#
# Fusing layers...
# Model summary: 165 layers, 7401119 parameters, 0 gradients, 25.7 GFLOPs
# val: Scanning /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Was
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         94       1049      0.818      0.788      0.819      0.639      0.734      0.689      0.683      0.524
#                plastic         94        942      0.676      0.676      0.712      0.388      0.498      0.487       0.44      0.165
#                  river         94        107       0.96        0.9      0.926       0.89      0.969       0.89      0.926      0.883
# Speed: 1.9ms pre-process, 7.6ms inference, 8.4ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val-seg/exp
# terminate called without an active exception

# %% [markdown]
# ## Inference with custom model
# Next, we can try out inferring with our custom model. We'll pass an example image. In the notebook, note that we grab one of the images that comes in the test set folder that comes from the Roboflow data loader. This ensures that we're truly testing on an image our model did not see in training.

# %%
# !python segment/predict.py --img 640 --weights runs/train-seg/exp/weights/best.pt --source ./Aerial_River_Plastic_Wastes-10/test/images/
# Out:
# segment/predict: weights=['runs/train-seg/exp/weights/best.pt'], source=./Aerial_River_Plastic_Wastes-10/test/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-392-gf003c3df Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
#
# Fusing layers...
# Model summary: 165 layers, 7401119 parameters, 0 gradients, 25.7 GFLOPs
# image 1/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_108_jpg.rf.0cd592574b46ddf6aa2e71c6b5240fc1.jpg: 640x640 17 plastics, 1 river, 7.3ms
# image 2/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_120_jpg.rf.e14b0782d7d1057f187c3885b9101ed2.jpg: 640x640 8 plastics, 1 river, 7.1ms
# image 3/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_122_jpg.rf.a3450937e6d66ebea12a3d53b9c70b1b.jpg: 640x640 9 plastics, 1 river, 7.2ms
# image 4/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_153_jpg.rf.d6f4c6202d61c3e837f0b2c990e62e08.jpg: 640x640 27 plastics, 1 river, 7.3ms
# image 5/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_17_jpg.rf.5a17f2f214b4f1e10684166b4982134e.jpg: 640x640 14 plastics, 1 river, 7.3ms
# image 6/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_189_jpg.rf.903b656630c3781f2311a7a63d8a2a32.jpg: 640x640 8 plastics, 3 rivers, 7.2ms
# image 7/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_192_jpg.rf.66ce105417d7ec8a644795a2d77a0edd.jpg: 640x640 6 plastics, 1 river, 7.2ms
# image 8/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_1_jpg.rf.a45a1d001fc297b886ee570498e6e226.jpg: 640x640 9 plastics, 1 river, 7.4ms
# image 9/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1_208_jpg.rf.227fdaeae9b65159133a3ed4c3c87d6f.jpg: 640x640 8 plastics, 1 river, 7.3ms
# image 10/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_1
95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_404_JPG.rf.5620f77fe2c07da0482dc90f936f354e.jpg: 640x640 5 plastics, 1 river, 7.2ms
# image 81/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_40_JPG.rf.3df48248b7784a9c3abed3417630a445.jpg: 640x640 1 plastic, 1 river, 7.2ms
# image 82/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_43_JPG.rf.a1b6adf51c81fd5e1b0638a561f74052.jpg: 640x640 1 plastic, 1 river, 7.2ms
# image 83/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_449_JPG.rf.e9e1003020e982d26d61821e9489312c.jpg: 640x640 3 plastics, 1 river, 7.3ms
# image 84/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_453_JPG.rf.2ac72e3ff6a25cd06e530490c45bc310.jpg: 640x640 3 plastics, 1 river, 7.3ms
# image 85/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_455_JPG.rf.8509aec6a660089f15667a5d9af44794.jpg: 640x640 3 plastics, 1 river, 7.3ms
# image 86/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_462_JPG.rf.b47cfaf1cca23723438abad18230c4ec.jpg: 640x640 2 plastics, 1 river, 7.2ms
# image 87/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_466_JPG.rf.9c70310cc7c70beb671b6d4af2983f7a.jpg: 640x640 2 plastics, 1 river, 7.2ms
# image 88/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_47_JPG.rf.b75536aa8d9bb3f791670180d178aab1.jpg: 640x640 2 plastics, 1 river, 7.3ms
# image 89/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_501_JPG.rf.2bb4217ce8e26ef6ebf5fef82a7ecb3b.jpg: 640x640 1 plastic, 1 river, 7.2ms
# image 90/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_502_JPG.rf.1c466e12b16662fbb109a9cfa8765a77.jpg: 640x640 1 plastic, 1 river, 7.2ms
# image 91/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_503_JPG.rf.8f0228d56264bb25746d409737ed8e7b.jpg: 640x640 1 plastic, 1 river, 7.2ms
# image 92/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_58_JPG.rf.e4761aff5ca117b24f4bb3c848a8ff97.jpg: 640x640 2 plastics, 1 river, 7.2ms
# image 93/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_64_JPG.rf.d2e02064be28e430e6f87e8724ca3176.jpg: 640x640 2 plastics, 1 river, 7.2ms
# image 94/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_65_JPG.rf.4f38023ba3239a7a7593df381a8db9da.jpg: 640x640 2 plastics, 1 river, 7.1ms
# image 95/95 /kaggle/working/yolo5/yolov5/yolo5/yolov5/Aerial_River_Plastic_Wastes-10/test/images/Aerial_Location_2_81_JPG.rf.6b27a1380acf1f90a2480cd3aaae2334.jpg: 640x640 3 plastics, 1 river, 7.2ms
# Speed: 0.5ms pre-process, 7.2ms inference, 2.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/predict-seg/exp

# %% [markdown]
# ## Downloading The results

# %%
# %ls
# Out:
# Aerial_River_Plastic_Wastes-10/  detect.py     pyproject.toml    train.py
# benchmarks.py                    export.py     README.md         tutorial.ipynb
# CITATION.cff                     hubconf.py    README.zh-CN.md   utils/
# classify/                        LICENSE       requirements.txt  val.py
# CONTRIBUTING.md                  models/       runs/             weights/
# data/                            __pycache__/  segment/          yolov5s-seg.pt

# %%
import shutil

# %cd ..
# Out:
# /kaggle/working/yolo5/yolov5/yolo5

# %%
# %ls
# Out:
# yolov5/

# %%
shutil.make_archive("1_yolo5_result", 'zip', "./yolov5")
# Out:
# '/kaggle/working/yolo5/yolov5/yolo5/1_yolo5_result.zip'

# %%
from google.colab import files

# Download the created ZIP file
#files.download('/kaggle/working/yolo5/yolov5/yolo5/1_yolo5_result.zip')
