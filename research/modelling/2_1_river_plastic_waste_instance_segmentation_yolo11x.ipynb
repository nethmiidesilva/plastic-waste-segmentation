# %%
import os
HOME = '/home/anokitv/anoubhav/action_recognition/obj/yolov11_code/'

# %%
# %pip install ultralytics supervision roboflow -U
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# ...
#   Using cached torchaudio-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.4 kB)
# ...
# Using cached torchaudio-2.5.1-cp312-cp312-manylinux1_x86_64.whl (3.4 MB)
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.57 🚀 Python-3.12.8 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# Setup complete ✅ (64 CPUs, 503.5 GB RAM, 1448.7/1749.5 GB disk)

# %%
current_path = os.environ.get("LD_LIBRARY_PATH", "")
current_path

### Path to nvidia lib - BELOW IS DONE TO AVOID THIS ERROR: https://github.com/pytorch/pytorch/issues/111469 when running locally
new_path = "/xxx/lib/python3.12/site-packages/nvidia/nvjitlink/lib"
# Update LD_LIBRARY_PATH
os.environ["LD_LIBRARY_PATH"] = f"{new_path}:{current_path}"

# Verify the change
print("LD_LIBRARY_PATH:", os.environ["LD_LIBRARY_PATH"])

# %%
# %cd data_yolov11/

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="U37Y1VWgripWggOxgiCE")
project = rf.workspace("project-zero").project("aerial_river_plastic_wastes")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd ..

# %%
len(os.listdir(os.path.join(dataset.location, 'valid/images'))), len(os.listdir(os.path.join(dataset.location, 'train/images')))
# Out:
# (94, 2274)

# %%
# !yolo task=segment mode=train model=yolo11x-seg.pt data={dataset.location}/data.yaml epochs=200 plots=True batch=32 device=0,1,2,3 \
save=True imgsz=640 save_period=5 seed=0 name='extra_large_runs'
# Out:
# ...
# 100%|█████████████████████████████████████████| 119M/119M [00:00<00:00, 320MB/s]
# New https://pypi.org/project/ultralytics/8.3.57 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.2 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:1 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:2 (NVIDIA GeForce RTX 4090, 24217MiB)
#                                                       CUDA:3 (NVIDIA GeForce RTX 4090, 24217MiB)
# ...
